# %%
import pandas

# %%
df = pandas.read_csv("hotels.csv")

# %%
print(df)
# Out:
#     id                     name        city  capacity available
# 0  134  Tourist Sunny Apartment   Anchorage         4       yes
# 1  188              Snow Palace   New Delhi         5        no
# 2  655           City Break Inn  Porto-Novo         3        no

# %%
id = df[df['id'] == 134]
print(id)
# Out:
#     id                     name       city  capacity available
# 0  134  Tourist Sunny Apartment  Anchorage         4       yes

# %% [markdown]
# # Check available

# %%
id = input("Enter hotel id: ")

hotel_id = int(id)

a = df.loc[df['id'] == hotel_id, 'available'].squeeze()

print("Availability:", a)
# Out:
# Enter hotel id:  134
# Availability: yes

# %%
print(id)
# Out:
# 0    134
# 1    188
# 2    655
# Name: id, dtype: int64
