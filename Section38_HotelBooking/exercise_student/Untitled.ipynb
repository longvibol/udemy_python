# %%
import pandas

# %%
df = pandas.read_csv("Resources/articles.csv")
print(df)
# Out:
#     id            name   price  in stock
# 0  100  laptop sven 10  999.00        87
# 1  101     mouse clara   12.99        87

# %%
a = df.loc[df['id'] == 100, 'name'].squeeze()
print(a)
# Out:
# laptop sven 10
