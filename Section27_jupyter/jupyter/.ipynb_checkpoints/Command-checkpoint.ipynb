# %% [markdown]
# # load data frame

# %% [markdown]
# import pandas as pd

# %%
df = pd.read_csv("data_small/TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("data_small/TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Show list of data

# %%
df[10:20]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0

# %% [markdown]
# # Use Alt+Enter to create new command line

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='object')

# %%
df['   TG']
# Out:
# 0          21
# 1          46
# 2          31
# 3          37
# 4          31
#          ...
# 59316   -9999
# 59317   -9999
# 59318   -9999
# 59319   -9999
# 59320   -9999
# Name:    TG, Length: 59321, dtype: int64

# %% [markdown]
# ## see more colums

# %%
df[['   TG','    DATE']]
# Out:
#          TG       DATE
# 0        21 1860-01-01
# 1        46 1860-01-02
# 2        31 1860-01-03
# 3        37 1860-01-04
# 4        31 1860-01-05
# ...     ...        ...
# 59316 -9999 2022-05-27
# 59317 -9999 2022-05-28
# 59318 -9999 2022-05-29
# 59319 -9999 2022-05-30
# 59320 -9999 2022-05-31
#
# [59321 rows x 2 columns]

# %% [markdown]
# # condition : df.loc[condition]

# %%
df.loc[df['   TG'] != -9999]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %% [markdown]
# # Find the average

# %%
df.loc[df['   TG'] != -9999]['   TG'].mean()/10
# Out:
# np.float64(6.360787526128467)

# %% [markdown]
# # Find max

# %%
df.loc[df['   TG'] != -9999]['   TG'].max()/10
# Out:
# np.float64(26.2)

# %% [markdown]
# # cc to copy the cell then v to parse

# %%
df.loc[df['   TG'] != -9999]['   TG'].max()/10
# Out:
# np.float64(26.2)

# %% [markdown]
# # histargram

# %%
df.loc[df['   TG'] != -9999]['   TG'].hist()
# Out:
# <Axes: >

# %%
df.loc[df['    DATE'] == '1860-01-03']
# Out:
#    STAID   SOUID       DATE     TG   Q_TG
# 2      1   35381 1860-01-03     31      0

# %%
df.loc[df['    DATE'] == '1860-01-03']['   TG'].squeeze()/10
# Out:
# np.float64(3.1)

# %% [markdown]
# # Get maximum date

# %%
df.loc[df['   TG'] == df['   TG'].max()]
# Out:
#       STAID   SOUID       DATE     TG   Q_TG
# 3150      1   35381 1868-08-16    262      0

# %% [markdown]
# # Get cell

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %%
df.loc[3,'   TG']
# Out:
# np.int64(37)

# %% [markdown]
# # Calculate new colume

# %%
df["TG"]=df['   TG']/10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["TG"]=df['   TG']/10
#
# NameError: name 'df' is not defined
