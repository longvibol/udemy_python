# %%
import pandas as pd

# %%
dic=pd.read_csv("dictionary.csv")

# %%
dic
# Out:
#                             word  \
# 0      abandoned industrial site
# 1              abandoned vehicle
# 2                 abiotic factor
# 3                    access road
# 4              access to the sea
# ...                          ...
# 49532                     casing
# 49533                     facing
# 49534                     lining
# 49535         assumption of Mary
# 49536               auscultation
#
#                                               definition
# 0      Site that cannot be used for any purpose, bein...
# 1      A vehicle that has been discarded in the envir...
# 2      Physical, chemical and other non-living enviro...
# 3      Any street or narrow stretch of paved surface ...
# 4      The ability to bring goods to and from a port ...
# ...                                                  ...
# 49532  Something put around something else, usually i...
# 49533  Something put around something else, usually i...
# ...

# %%
dic.columns
# Out:
# Index(['word', 'definition'], dtype='object')

# %%
definition = dic.loc[dic['word'] == 'access road']['definition']

# %%
definition
# Out:
# 3    Any street or narrow stretch of paved surface ...
# Name: definition, dtype: object

# %%
word = dic['word']

# %%
word
# Out:
# 0        abandoned industrial site
# 1                abandoned vehicle
# 2                   abiotic factor
# 3                      access road
# 4                access to the sea
#                    ...
# 49532                       casing
# 49533                       facing
# 49534                       lining
# 49535           assumption of Mary
# 49536                 auscultation
# Name: word, Length: 49537, dtype: object

# %%
definistion = dic['definition']

# %%
definistion
# Out:
# 0        Site that cannot be used for any purpose, bein...
# 1        A vehicle that has been discarded in the envir...
# 2        Physical, chemical and other non-living enviro...
# 3        Any street or narrow stretch of paved surface ...
# 4        The ability to bring goods to and from a port ...
#                                ...
# 49532    Something put around something else, usually i...
# 49533    Something put around something else, usually i...
# 49534    Something put around something else, usually i...
# 49535    Catholic holiday on August 15, remembering the...
# 49536    Listening to the heart and lungs using a steth...
# Name: definition, Length: 49537, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 word[definistion]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:1165, in Series.__getitem__(self, key)
#    1162     key = np.asarray(key, dtype=bool)
#    1163     return self._get_rows_with_mask(key)
# -> 1165 return self._get_with(key)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:1206, in Series._get_with(self, key)
#    1203         return self.iloc[key]
#    1205 # handle the dup indexing case GH#4246
# -> 1206 return self.loc[key]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
# ...
